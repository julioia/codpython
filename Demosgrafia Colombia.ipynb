# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = 'https://es.wikipedia.org/wiki/Demograf%C3%ADa_de_Colombia'

# %%
dataframe = pd.io.html.read_html(url)

# %%
dataframe
# Out:
# [         Demografía de Colombia  \
#  0                     Población
#  1                      Densidad
#  2           Tasa de crecimiento
#  3             Tasa de natalidad
#  4            Tasa de mortalidad
#  5             Esperanza de vida
#  6                     • Varones
#  7                     • Mujeres
#  8            Tasa de fertilidad
#  9   Tasa de mortalidad infantil
#  10        Estructura por edades
#  11                    < 15 años
#  12                   15-64 años
#  13                    > 65 años
#  14       Índice de masculinidad
#  15                Al nacimiento
#  16                 Nacionalidad
#  17                 Nacionalidad
#  18               Mayoría étnica
#  19             Minorías étnicas
#  20                      Idiomas
#  21                      Oficial
#  22                     Hablados
#  23   [editar datos en Wikidata]
#
#                               Demografía de Colombia.1  \
#  0                                      51 343 921[1]​
# ...

# %%
dataframe_poblacion = dataframe[0]
dataframe_poblacion
# Out:
#          Demografía de Colombia  \
# 0                     Población
# 1                      Densidad
# 2           Tasa de crecimiento
# 3             Tasa de natalidad
# 4            Tasa de mortalidad
# 5             Esperanza de vida
# 6                     • Varones
# 7                     • Mujeres
# 8            Tasa de fertilidad
# 9   Tasa de mortalidad infantil
# 10        Estructura por edades
# 11                    < 15 años
# 12                   15-64 años
# 13                    > 65 años
# 14       Índice de masculinidad
# 15                Al nacimiento
# 16                 Nacionalidad
# 17                 Nacionalidad
# 18               Mayoría étnica
# 19             Minorías étnicas
# 20                      Idiomas
# 21                      Oficial
# 22                     Hablados
# 23   [editar datos en Wikidata]
#
#                              Demografía de Colombia.1  \
# 0                                      51 343 921[1]​
# ...

# %%
dict(dataframe_poblacion.loc[0])
# Out:
# {'Demografía de Colombia': 'Población',
#  'Demografía de Colombia.1': '51 343 921[1]\u200b',
#  'Demografía de Colombia.2': '51 343 921[1]\u200b'}

# %%
pelotas_fronton = [51, 45, 19.5, 6.1, 77]
nombres = ["Poblacion","Densidad de habitantes","Tasa de natalidad","Tasa de moratalidad","Esperanza de vida"]

# %%
plt.pie(
    x = pelotas_fronton,
    labels = nombres
)
plt.show()
